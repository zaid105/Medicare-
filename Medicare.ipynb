# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\zaida\OneDrive\Desktop\Machine Learning\Medicare Dataset.csv",low_memory=False)

# %%
df
# Out:
#        Rndrng_Prvdr_Geo_Lvl Rndrng_Prvdr_Geo_Cd Rndrng_Prvdr_Geo_Desc  \
# 0                  National                 NaN              National
# 1                  National                 NaN              National
# 2                  National                 NaN              National
# 3                  National                 NaN              National
# 4                  National                 NaN              National
# ...                     ...                 ...                   ...
# 271630                State                  9E       Foreign Country
# 271631                State                  9E       Foreign Country
# 271632                State                  9E       Foreign Country
# 271633                State                  9E       Foreign Country
# 271634                State                  9E       Foreign Country
#
#        HCPCS_Cd                                         HCPCS_Desc  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271635 entries, 0 to 271634
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Rndrng_Prvdr_Geo_Lvl   271635 non-null  object
#  1   Rndrng_Prvdr_Geo_Cd    258353 non-null  object
#  2   Rndrng_Prvdr_Geo_Desc  271635 non-null  object
#  3   HCPCS_Cd               271635 non-null  object
#  4   HCPCS_Desc             271635 non-null  object
#  5   HCPCS_Drug_Ind         271635 non-null  object
#  6   Place_Of_Srvc          271635 non-null  object
#  7   Tot_Rndrng_Prvdrs      271635 non-null  int64
#  8   Tot_Benes              271635 non-null  int64
#  9   Tot_Srvcs              271635 non-null  float64
#  10  Tot_Bene_Day_Srvcs     271635 non-null  int64
#  11  Avg_Sbmtd_Chrg         271635 non-null  float64
#  12  Avg_Mdcr_Alowd_Amt     271635 non-null  float64
#  13  Avg_Mdcr_Pymt_Amt      271635 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Tot_Rndrng_Prvdrs     Tot_Benes     Tot_Srvcs  Tot_Bene_Day_Srvcs  \
# count      271635.000000  2.716350e+05  2.716350e+05        2.716350e+05
# mean          265.619073  5.675854e+03  2.323802e+04        1.070440e+04
# std          3245.051853  1.182706e+05  6.054120e+05        3.110772e+05
# min             1.000000  1.100000e+01  1.100000e+01        1.100000e+01
# 25%            12.000000  3.000000e+01  4.000000e+01        3.800000e+01
# 50%            29.000000  1.060000e+02  1.610000e+02        1.430000e+02
# 75%            95.000000  5.850000e+02  1.084000e+03        8.320000e+02
# max        589381.000000  2.189095e+07  1.145324e+08        8.951697e+07
#
#        Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  Avg_Mdcr_Pymt_Amt  \
# count   271635.000000       271635.000000      271635.000000
# mean      1280.171818          297.485532         237.741823
# std       2439.147062          792.999187         636.833732
# min          0.000345            0.000000           0.000000
# ...

# %%
df.columns
# Out:
# Index(['Rndrng_Prvdr_Geo_Lvl', 'Rndrng_Prvdr_Geo_Cd', 'Rndrng_Prvdr_Geo_Desc',
#        'HCPCS_Cd', 'HCPCS_Desc', 'HCPCS_Drug_Ind', 'Place_Of_Srvc',
#        'Tot_Rndrng_Prvdrs', 'Tot_Benes', 'Tot_Srvcs', 'Tot_Bene_Day_Srvcs',
#        'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Alowd_Amt', 'Avg_Mdcr_Pymt_Amt',
#        'Avg_Mdcr_Stdzd_Amt'],
#       dtype='object')

# %%
# Drop it is numeric code for Rndrng_prvdr_Geo_Desc
df = df.drop("Rndrng_Prvdr_Geo_Cd",axis=1)

# %%
df
# Out:
#        Rndrng_Prvdr_Geo_Lvl Rndrng_Prvdr_Geo_Desc HCPCS_Cd  \
# 0                  National              National    0001A
# 1                  National              National    0001A
# 2                  National              National    0002A
# 3                  National              National    0002A
# 4                  National              National    0003A
# ...                     ...                   ...      ...
# 271630                State       Foreign Country    G0439
# 271631                State       Foreign Country    G0447
# 271632                State       Foreign Country    J1030
# 271633                State       Foreign Country    J1885
# 271634                State       Foreign Country    J3301
#
#                                                HCPCS_Desc HCPCS_Drug_Ind  \
# 0                            Adm sarscov2 30mcg/0.3ml 1st              N
# 1                            Adm sarscov2 30mcg/0.3ml 1st              N
# ...

# %%
# Cheacking Nans
df.isna().sum()
# Out:
# Rndrng_Prvdr_Geo_Lvl     0
# Rndrng_Prvdr_Geo_Desc    0
# HCPCS_Cd                 0
# HCPCS_Desc               0
# HCPCS_Drug_Ind           0
# Place_Of_Srvc            0
# Tot_Rndrng_Prvdrs        0
# Tot_Benes                0
# Tot_Srvcs                0
# Tot_Bene_Day_Srvcs       0
# Avg_Sbmtd_Chrg           0
# Avg_Mdcr_Alowd_Amt       0
# Avg_Mdcr_Pymt_Amt        0
# Avg_Mdcr_Stdzd_Amt       0
# dtype: int64

# %% [markdown]
# ### Visualization

# %%
# Pie Diagram of Place_of_Srvc
df.Place_Of_Srvc.value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Pie Diagram of HCPCS_Drug_Ind
df.HCPCS_Drug_Ind.value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Pie Diagram of Rndrng_Prvdr_Geo_Lvl
df.Rndrng_Prvdr_Geo_Lvl.value_counts().plot(kind="pie",autopct="%.2F%%")
# Out:
# <Axes: ylabel='count'>

# %%
# Cluster column chart Avg_Mdcr_Pymt_Amt of Place_of_src
ax = df.Avg_Mdcr_Pymt_Amt.groupby(df.Place_Of_Srvc).mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Cluster column chart tot_Benes of Place_of_src
ax = df.Tot_Benes.groupby(df.Place_Of_Srvc).mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Cluster column chart tot_Srvcs of Place_of_src
ax = df.Tot_Srvcs.groupby(df.Place_Of_Srvc).mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Cluster Column chart of Rndrg_prvder_geo
plt.figure(figsize=(16,12))
df.Rndrng_Prvdr_Geo_Desc.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Rndrng_Prvdr_Geo_Desc'>

# %%
# Cluster Column chart of Rndrg_prvder_geo_desc wise Tot_rndrg_prvdrs
plt.figure(figsize=(20,12))
ax = df.Tot_Rndrng_Prvdrs.groupby(df.Rndrng_Prvdr_Geo_Desc).mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)

# %%
ax = pd.crosstab(df.Rndrng_Prvdr_Geo_Lvl,df.Place_Of_Srvc).plot(kind="bar",stacked = True)
for i in ax.containers:
    ax.bar_label(i)

# %%
# Clustered column chart Average Avg_Mdcr_pymt of Rndrg_Prvvdr_Geo
ax = df.Avg_Mdcr_Pymt_Amt.groupby(df.Rndrng_Prvdr_Geo_Lvl).mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Clustered column chart Average tot bones of Rndrg_Prvvdr_Geo
ax = df.Tot_Benes.groupby(df.Rndrng_Prvdr_Geo_Lvl).mean().plot(kind="bar")
for i in ax.containers:
    ax.bar_label(i)

# %%
# Descriptive Statistic - Avg_Mdcr_Pymt_Amt

# %%
df.Avg_Mdcr_Pymt_Amt.describe()
# Out:
# count    271635.000000
# mean        237.741823
# std         636.833732
# min           0.000000
# 25%          28.569204
# 50%          89.256379
# 75%         260.171596
# max       41624.174414
# Name: Avg_Mdcr_Pymt_Amt, dtype: float64

# %%
# Right Skewed data
sns.distplot(df.Avg_Mdcr_Pymt_Amt)
# Out:
# <Axes: xlabel='Avg_Mdcr_Pymt_Amt', ylabel='Density'>

# %%
df.Avg_Mdcr_Pymt_Amt.skew()
# Out:
# 32.18128987373379

# %%
# Kurtosis
df.Avg_Mdcr_Pymt_Amt.kurt()
# Out:
# 1844.6230558699967

# %%
# Descriptive Statistic - Tot_srvc

# %%
df.Tot_Srvcs.describe()
# Out:
# count    2.716350e+05
# mean     2.323802e+04
# std      6.054120e+05
# min      1.100000e+01
# 25%      4.000000e+01
# 50%      1.610000e+02
# 75%      1.084000e+03
# max      1.145324e+08
# Name: Tot_Srvcs, dtype: float64

# %%
df.Tot_Srvcs.skew()
# Out:
# 100.89163232201754

# %%
# Distplot 
sns.distplot(df.Tot_Srvcs)
# Out:
# <Axes: xlabel='Tot_Srvcs', ylabel='Density'>

# %%
# Kurtosis
df.Tot_Srvcs.kurt()
# Out:
# 13452.451033427304

# %%
df.columns
# Out:
# Index(['Rndrng_Prvdr_Geo_Lvl', 'Rndrng_Prvdr_Geo_Desc', 'HCPCS_Cd',
#        'HCPCS_Desc', 'HCPCS_Drug_Ind', 'Place_Of_Srvc', 'Tot_Rndrng_Prvdrs',
#        'Tot_Benes', 'Tot_Srvcs', 'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg',
#        'Avg_Mdcr_Alowd_Amt', 'Avg_Mdcr_Pymt_Amt', 'Avg_Mdcr_Stdzd_Amt'],
#       dtype='object')

# %%
df.drop(["HCPCS_Cd","HCPCS_Desc",],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Rndrng_Prvdr_Geo_Lvl Rndrng_Prvdr_Geo_Desc HCPCS_Drug_Ind Place_Of_Srvc  \
# 0             National              National              N             F
# 1             National              National              N             O
# 2             National              National              N             F
# 3             National              National              N             O
# 4             National              National              N             F
#
#    Tot_Rndrng_Prvdrs  Tot_Benes  Tot_Srvcs  Tot_Bene_Day_Srvcs  \
# 0                279      25735    26341.0               26341
# 1              57563    9080086  9346114.7             9345929
# 2                187      24576    24649.0               24649
# 3              52326    8897346  8994332.2             8994143
# 4                211       5364     5371.0                5371
#
#    Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  Avg_Mdcr_Pymt_Amt  Avg_Mdcr_Stdzd_Amt
# ...

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# #### Test null Average avg_Mdcr_Pymt_Amt for Place_of_srvc is equal

# %%
df.Avg_Mdcr_Pymt_Amt.groupby(df.Place_Of_Srvc).mean()
# Out:
# Place_Of_Srvc
# F    295.256312
# O    172.634904
# Name: Avg_Mdcr_Pymt_Amt, dtype: float64

# %%
df.Avg_Mdcr_Pymt_Amt.groupby(df.Place_Of_Srvc).var()
# Out:
# Place_Of_Srvc
# F    177885.357807
# O    655303.629523
# Name: Avg_Mdcr_Pymt_Amt, dtype: float64

# %%
# Splitting
Fclass = df[df.Place_Of_Srvc == "F"] 
Oclass = df[df.Place_Of_Srvc == "O"]

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(Fclass.Avg_Mdcr_Pymt_Amt,Oclass.Avg_Mdcr_Pymt_Amt)
# Since pvalue=1.0331351382064729e-25 is less than 0.05 - Reject null
# Out:
# TtestResult(statistic=50.313263979755455, pvalue=0.0, df=271633.0)

# %% [markdown]
# ####  Test null Average Tot_bane_day_srvc for place-of_srvc is equal

# %%
df.Tot_Bene_Day_Srvcs.groupby(df.Place_Of_Srvc).mean()
# Out:
# Place_Of_Srvc
# F     4824.134614
# O    17360.911536
# Name: Tot_Bene_Day_Srvcs, dtype: float64

# %%
# Splitting
Fclass = df[df.Place_Of_Srvc == "F"] 
Oclass = df[df.Place_Of_Srvc == "O"]

# %%
ttest_ind(Fclass.Tot_Bene_Day_Srvcs,Oclass.Tot_Bene_Day_Srvcs)
# Since pvalue=1.0331351382064729e-25 is less than 0.05 - Reject null
# Out:
# TtestResult(statistic=-10.484158632719023, pvalue=1.0331351382064729e-25, df=271633.0)

# %% [markdown]
# ####  Test null no assosiation between Rndrng_prvdng_Geo_lvl and place_of_srvc

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(pd.crosstab(df.Rndrng_Prvdr_Geo_Lvl,df.Place_Of_Srvc))
# Since pvalue=0.548014490212158 is greater than 0.05 - Fail to reject null
# Out:
# Chi2ContingencyResult(statistic=0.36088617114963045, pvalue=0.548014490212158, dof=1, expected_freq=array([[  7052.19509268,   6229.80490732],
#        [137174.80490732, 121178.19509268]]))

# %%
# Cheack for Multicollinearity among variables
df[['Tot_Rndrng_Prvdrs',
       'Tot_Benes', 'Tot_Srvcs', 'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg',
       'Avg_Mdcr_Alowd_Amt', 'Avg_Mdcr_Pymt_Amt','Avg_Mdcr_Stdzd_Amt']].corr()
# Out:
#                     Tot_Rndrng_Prvdrs  Tot_Benes  Tot_Srvcs  \
# Tot_Rndrng_Prvdrs            1.000000   0.685156   0.392200
# Tot_Benes                    0.685156   1.000000   0.479181
# Tot_Srvcs                    0.392200   0.479181   1.000000
# Tot_Bene_Day_Srvcs           0.698055   0.846001   0.570929
# Avg_Sbmtd_Chrg              -0.019574  -0.019822  -0.018037
# Avg_Mdcr_Alowd_Amt          -0.014934  -0.013196  -0.012290
# Avg_Mdcr_Pymt_Amt           -0.015018  -0.013083  -0.012242
# Avg_Mdcr_Stdzd_Amt          -0.014993  -0.012996  -0.012142
#
#                     Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  \
# Tot_Rndrng_Prvdrs             0.698055       -0.019574           -0.014934
# Tot_Benes                     0.846001       -0.019822           -0.013196
# Tot_Srvcs                     0.570929       -0.018037           -0.012290
# Tot_Bene_Day_Srvcs            1.000000       -0.014617           -0.009580
# ...

# %%
sns.heatmap(df[['Tot_Rndrng_Prvdrs',
       'Tot_Benes', 'Tot_Srvcs', 'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg',
       'Avg_Mdcr_Alowd_Amt', 'Avg_Mdcr_Pymt_Amt','Avg_Mdcr_Stdzd_Amt']].corr(),annot=True,cmap="plasma")
# Out:
# <Axes: >

# %%
# Multicollinearity between Avg_Mdcr_allowed_amt , Avg_Mdcr_Pymt_Amt ,Avg_Mdcr_stdzd_Amt 
# Avg_Mdcr_Pymt_Amt is a dependent vairiable
# Drop "Avg_Mdcr_allowed_Amt" & Avg_Mdcr_stdzd_Amt

# %%
df.drop(["Avg_Mdcr_Alowd_Amt",'Avg_Mdcr_Stdzd_Amt'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   Rndrng_Prvdr_Geo_Lvl Rndrng_Prvdr_Geo_Desc HCPCS_Drug_Ind Place_Of_Srvc  \
# 0             National              National              N             F
# 1             National              National              N             O
# 2             National              National              N             F
# 3             National              National              N             O
# 4             National              National              N             F
#
#    Tot_Rndrng_Prvdrs  Tot_Benes  Tot_Srvcs  Tot_Bene_Day_Srvcs  \
# 0                279      25735    26341.0               26341
# 1              57563    9080086  9346114.7             9345929
# 2                187      24576    24649.0               24649
# 3              52326    8897346  8994332.2             8994143
# 4                211       5364     5371.0                5371
#
#    Avg_Sbmtd_Chrg  Avg_Mdcr_Pymt_Amt
# 0       42.415088          20.884538
# 1       44.186609          25.759086
# ...

# %%
df.columns
# Out:
# Index(['Rndrng_Prvdr_Geo_Lvl', 'Rndrng_Prvdr_Geo_Desc', 'HCPCS_Drug_Ind',
#        'Place_Of_Srvc', 'Tot_Rndrng_Prvdrs', 'Tot_Benes', 'Tot_Srvcs',
#        'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Pymt_Amt'],
#       dtype='object')

# %%
# Dummy incoding:
df = pd.get_dummies(df,columns=['Rndrng_Prvdr_Geo_Lvl', 'Rndrng_Prvdr_Geo_Desc', 'HCPCS_Drug_Ind',
       'Place_Of_Srvc'])

# %%
df
# Out:
#         Tot_Rndrng_Prvdrs  Tot_Benes  Tot_Srvcs  Tot_Bene_Day_Srvcs  \
# 0                     279      25735    26341.0               26341
# 1                   57563    9080086  9346114.7             9345929
# 2                     187      24576    24649.0               24649
# 3                   52326    8897346  8994332.2             8994143
# 4                     211       5364     5371.0                5371
# ...                   ...        ...        ...                 ...
# 271630                  4         77       77.0                  77
# 271631                  1         26       51.0                  51
# 271632                  2         15       19.0                  17
# 271633                  3         11       16.0                  11
# 271634                  2         22      118.0                  27
#
#         Avg_Sbmtd_Chrg  Avg_Mdcr_Pymt_Amt  Rndrng_Prvdr_Geo_Lvl_National  \
# 0            42.415088          20.884538                           True
# ...

# %%
# Splitting Data into dependent and independent variables

# %%
X = df.drop('Avg_Mdcr_Pymt_Amt',axis=1)

# %%
y = df.Avg_Mdcr_Pymt_Amt

# %%
# Histogram, boxplot and Density curve of y

# %%
fig,ax = plt.subplots(3,1)
sns.histplot(y,ax=ax[0])
sns.boxplot(y,ax=ax[1],orient="h")
sns.kdeplot(y,ax=ax[2])
plt.show()

# %%
# Logarithmic Transformation due to very high positive skewness
fig,ax = plt.subplots(3,1)
sns.histplot(np.log(y),ax=ax[0])
sns.boxplot(np.log(y),ax=ax[1],orient="h")
sns.kdeplot(np.log(y),ax=ax[2])
plt.show()

# %% [markdown]
# ###

# %% [markdown]
# ### Model Building

# %% [markdown]
# #### Linear Rigression

# %%
from sklearn.linear_model import LinearRegression

# %%
LR = LinearRegression().fit(X,y)

# %%
LR.score(X,y)
# Out:
# 0.6327453953641551

# %%
regpred = LR.predict(X)

# %%
np.sqrt(np.mean((y-regpred)**2)) # RMSE
# Out:
# 385.93030686213194

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
DT = DecisionTreeRegressor(max_depth=8).fit(X,y)
DT.score(X,y)
# Out:
# 0.8862850494652839

# %%
from sklearn.model_selection import cross_val_score

# %%
v = cross_val_score(DT,X,y)

# %%
v.mean()
# Out:
# 0.8160346182143556

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF = RandomForestRegressor().fit(X,y)

# %%
RF.score(X,y)
# Out:
# 0.9828481199212226

# %% [markdown]
# #### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GB = GradientBoostingRegressor(n_estimators=500).fit(X,y)

# %%
GB.score(X,y)
# Out:
# 0.9105808625178521

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
gbpred = GB.predict(X)

# %%
print("MAE = ",mean_absolute_error(y,gbpred))
# Out:
# MAE =  79.36235924302385

# %%
print("MSE = ", mean_squared_error(y,gbpred))
# Out:
# MSE =  36264.44174553822

# %%
print("RMSE = ",np.sqrt((mean_squared_error(y,gbpred))))
# Out:
# RMSE =  190.43224975181653

# %%
r2 = (r2_score(y,gbpred))
print("R2 score",r2)
# Out:
# R2 score 0.9105808625178521
